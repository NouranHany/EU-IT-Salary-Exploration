# %%
# !pip install python-Levenshtein

# %%
from utils import *
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
def clean_pos_col(df):
    # Cleaning using fuzz library 
    positions = df['Position'].unique()
    standardized_positions = {}
    for position in positions:
        if position in standardized_positions:
            continue
        matches = process.extract(position, positions, scorer=fuzz.token_sort_ratio, limit=None)
        best_match, score = max(matches, key=lambda x: x[1])
        if score >= 80:
            standardized_positions[position] = best_match
            for synonym in matches:
                if synonym[1] >= 80:
                    standardized_positions[synonym[0]] = best_match
        else:
            standardized_positions[position] = position
    df['Position'] = df['Position'].map(standardized_positions)
    #Cleaning Manually 
    for i, row in df.iterrows():
        print(row['Position'])
        if row['Position'] in ['qa engineer' , 'qa lead' , 'qa manager' , 'working student(qa)']:
            df.at[i,'Position'] = 'qa'
        if row['Position'] in ['ну или software engineer']:
            df.at[i,'Position'] = 'software engineer'
        if row['Position'] in ['software developer in test']:
            df.at[i,'Position'] = 'software tester'
        if row['Position'] in ['lead software developer']:
            df.at[i,'Position'] = 'software developer'
        if row['Position'] in ['senior data engineer' , 'data science manager' , 'data science manager' , 'analyst']:
            df.at[i,'Position'] = 'data engineer'
        if row['Position'] in ['systemadministrator']:
            df.at[i,'Position'] = 'system administrator'
    df  = df[df['Position'] !='nan']
    return df

# %%
df1 = []
df = data_pre(df1)
df = df.apply(lambda x: x.astype(str).str.lower())
df['Position'].value_counts()
# Out:
# ['Startup' 'Product' nan 'Consulting / Agency' 'Bodyshop / Outsource'
#  'University' 'Bank' 'Outsource']
# Position
# backend developer         427
# software engineer         394
# data scientist            232
# frontend developer        157
# devops                    110
#                          ...
# tech lead / full-stack      1
# technical lead              1
# architect                   1
# hiwi                        1
# desktop                     1
# Name: count, Length: 167, dtype: int64

# %%
df = clean_pos_col(df)
# Out:
# software engineer
# backend developer
# software engineer
# frontend developer
# backend developer
# devops
# frontend developer
# frontend developer
# backend developer
# software engineer
# data engineer
# software engineer
# software engineer
# software engineer
# designer (ui/ux)
# backend developer
# backend developer
# product manager
# backend developer
# mobile developer
# devops
# software architect
# software engineer
# backend developer
# software engineer
# team lead
# devops
# test manager
# devops
# product manager
# software engineer
# backend developer
# qa engineer
# software engineer
# software engineer
# data scientist
# designer (ui/ux)
# software engineer
# backend developer
# devops
# frontend developer
# software engineer
# frontend developer
# software engineer
# software engineer
# software engineer
# designer (ui/ux)
# backend developer
# backend developer
# software engineer
# backend developer
# designer (ui/ux)
# qa engineer
# backend developer
# backend developer
# software engineer
# software engineer
# devops
# software engineer
# software engineer
# software engineer
# backend developer
# frontend developer
# software engineer
# frontend developer
# hardware engineer
# data scientist
# software engineer
# data engineer
# software engineer
# mobile developer
# backend developer
# software engineer
# software engineer
# engineering manager
# backend developer
# devops
# software engineer
# software engineer
# data scientist
# software engineer
# analytics engineer
# software engineer
# localization producer
# mobile developer
# software engineer
# software engineer
# qa engineer
# data scientist
# devops
# data scientist
# hardware engineer
# reporting engineer
# account managet
# product manager
# qa engineer
# software engineer
# agile master
# software engineer
# backend developer
# backend developer
# software engineer
# qa engineer
# software engineer
# software engineer
# frontend developer
# qa engineer
# nlp engineer
# software engineer
# data scientist
# solution architect
# frontend developer
# backend developer
# qa engineer
# backend developer
# software engineer
# qa engineer
# software engineer
# bi consultant
# backend developer
# mobile developer
# fullstack developer
# software engineer
# data scientist
# mobile developer
# product manager
# software engineer
# frontend developer
# frontend developer
# backend developer
# software engineer
# nan
# backend developer
# backend developer
# frontend developer
# product manager
# software engineer
# software engineer
# qa engineer
# backend developer
# software engineer
# cloud architect
# designer (ui/ux)
# system administrator
# software engineer
# data scientist
# frontend developer
# qa engineer
# software engineer
# product manager
# backend developer
# qa engineer
# product manager
# software engineer
# product manager
# software engineer
# software engineer
# software engineer
# frontend developer
# software engineer
# data scientist
# backend developer
# devops
# network engineer
# frontend developer
# qa engineer
# vp engineering
# backend developer
# backend developer
# agile coach
# software engineer
# mobile developer
# software engineer
# mobile developer
# qa engineer
# backend developer
# nlp engineer
# software engineer
# backend developer
# qa engineer
# software engineer
# software engineer
# mobile developer
# data science manager
# product manager
# devops
# data scientist
# scrum master
# mobile developer
# hardware engineer
# frontend developer
# qa engineer
# software engineer
# software engineer
# software engineer
# solution architect
# software engineer
# data center manager
# software engineer
# fullstack developer
# software engineer
# software engineer
# nlp engineer
# software engineer
# product manager
# mobile developer
# software engineer
# software engineer
# software engineer
# software engineer
# product manager
# software engineer
# designer (ui/ux)
# backend developer
# mobile developer
# data scientist
# qa engineer
# backend developer
# mobile developer
# backend developer
# engineering manager
# qa engineer
# devops
# backend developer
# software engineer
# c/c++/java developer
# backend developer
# mobile developer
# devops manager
# software engineer
# software engineer
# software engineer
# software engineer
# frontend developer
# nlp engineer
# engineering manager
# software engineer
# backend developer
# software engineer
# software engineer
# data scientist
# software engineer
# qa engineer
# backend developer
# nlp engineer
# qa engineer
# software engineer
# team lead
# tech lead
# network administrator
# security manager
# qa engineer
# consultant data analytics
# bi consultant
# graphic designer
# software engineer
# backend developer
# frontend developer
# ios developer
# banker
# data engineer
# backend developer
# cloud engineer
# product manager
# software engineer
# solution architect
# backend developer
# backend developer
# stuttgart
# mobile developer
# backend developer
# frontend developer
# senior program manager
# software engineer
# qa engineer
# qa engineer
# backend developer
# frontend developer
# backend developer
# product manager
# software engineer
# frontend developer
# qa engineer
# nlp engineer
# nlp engineer
# db developer/data analyst
# software engineer
# qa engineer
# software engineer
# software engineer
# backend developer
# security engineer
# software engineer
# devops
# backend developer
# software engineer
# software engineer
# business analyst
# nlp engineer
# backend developer
# data engineer
# dba
# backend developer
# devops
# support engineer
# frontend developer
# frontend developer
# software engineer
# software engineer
# software engineer
# software engineer
# mobile developer
# backend developer
# software engineer
# software engineer
# software engineer
# frontend developer
# sap consultant
# software engineer
# software engineer
# software engineer
# software engineer
# software engineer
# backend developer
# recruiter
# backend developer
# software engineer
# testautomation
# mobile developer
# software engineer
# data scientist
# qa engineer
# software engineer
# data scientist
# software engineer
# software engineer
# backend developer
# software engineer
# backend developer
# software engineer
# support engineer
# data scientist
# rpa developer
# frontend developer
# software engineer
# mobile developer
# backend developer
# software engineer
# software engineer
# systemadministrator
# backend developer
# devops
# software engineer
# architect
# software engineer
# sre
# software engineer
# software engineer
# backend developer
# software engineer
# backend developer
# qa engineer
# software engineer
# fullstack engineer, ну или software engineer
# backend developer
# software engineer
# hiwi
# backend developer
# software engineer
# software engineer
# product manager
# data engineer
# software engineer
# software engineer
# backend developer
# software engineer
# software engineer
# frontend developer
# backend developer
# backend developer
# software engineer
# software engineer
# software engineer
# software engineer
# software engineer
# software engineer
# mobile developer
# software engineer
# software engineer
# software engineer
# backend developer
# backend developer
# product manager
# software engineer
# product manager
# qa engineer
# software engineer
# backend developer
# data scientist
# security engineer
# software engineer
# software engineer
# data scientist
# software engineer
# designer (ui/ux)
# architect
# backend developer
# backend developer
# mobile developer
# frontend developer
# software engineer
# backend developer
# designer (ui/ux)
# software engineer
# technical lead
# backend developer
# frontend developer
# software engineer
# software engineer
# software engineer
# software engineer
# mobile developer
# backend developer
# devops
# backend developer
# frontend developer
# software engineer
# mobile developer
# qa engineer
# mobile developer
# backend developer
# nlp engineer
# tech lead / full-stack
# frontend developer
# software engineer
# devops
# frontend developer
# marketing analyst
# software engineer
# frontend developer
# mobile developer
# cto
# solution architect
# backend developer
# software engineer
# software engineer
# qa engineer
# data scientist
# frontend developer
# software engineer
# senior network&security eng.
# software tester
# fullstack developer
# frontend developer
# software engineer
# backend developer
# sap bw senior consultant
# software engineer
# mobile developer
# software engineer
# software engineer
# software engineer
# software engineer
# qa manager
# software engineer
# software engineer
# director of engineering
# it spezialist
# product manager
# software engineer
# software engineer
# software engineer
# qa engineer
# nan
# software engineer
# software engineer
# mobile developer
# software engineer
# frontend developer
# frontend developer
# software engineer
# software engineer
# engineering manager
# frontend developer
# nlp engineer
# designer (ui/ux)
# software engineer
# software engineer
# product manager
# software engineer
# software engineer
# software architect
# software engineer
# backend developer
# it manager
# software engineer
# software engineer
# data scientist
# nlp engineer
# data scientist
# data scientist
# software engineer
# software engineer
# software engineer
# mobile developer
# data scientist
# sap consultant
# frontend developer
# software engineer
# devops
# mobile developer
# software engineer
# data analyst
# qa engineer
# software engineer
# product manager
# devops
# frontend developer
# data scientist
# software engineer
# software engineer
# product manager
# data scientist
# frontend developer
# software developer in test
# data analyst
# mobile developer
# data scientist
# software architect
# software engineer
# frontend developer
# software engineer
# qa engineer
# software engineer
# technical account manager
# software engineer
# data scientist
# frontend developer
# data engineer
# software engineer
# software engineer
# data engineer
# data scientist
# software engineer
# data scientist
# software engineer
# software engineer
# devops
# software engineer
# qa engineer
# frontend developer
# frontend developer
# data scientist
# nlp engineer
# data scientist
# backend developer
# software engineer
# frontend developer
# tech lead
# chief research officer
# qa engineer
# sre
# nlp engineer
# data scientist
# data engineer
# data engineer
# data engineer
# product manager
# devops
# product manager
# presales engineer
# data scientist
# data scientist
# backend developer
# freelance ai lead / advisor
# data scientist
# data scientist
# devops
# software engineer
# data scientist
# frontend developer
# business development manager operations
# frontend developer
# frontend developer
# senior program manager
# frontend developer
# devops
# researcher
# product manager
# software engineer
# software engineer
# qa engineer
# qa engineer
# data scientist
# engineering manager
# software engineer
# software engineer
# data scientist
# data scientist
# backend developer
# qa engineer
# data scientist
# engineering manager
# backend developer
# software engineer
# data scientist
# software engineer
# software engineer
# backend developer
# backend developer
# nlp engineer
# qa engineer
# backend developer
# embedded software engineer
# software engineer
# backend developer
# product manager
# software engineer
# data analyst
# backend developer
# qa manager
# backend developer
# backend developer
# backend developer
# software engineer
# backend developer
# software engineer
# software engineer
# software engineer
# qa engineer
# software engineer
# software engineer
# data analyst
# software engineer
# devops
# devops
# data engineer
# software engineer
# software engineer
# data scientist
# software engineer
# software engineer
# software engineer
# data analyst
# data scientist
# mobile developer
# backend developer
# frontend developer
# software engineer
# frontend developer
# data engineer
# qa engineer
# nan
# mobile developer
# data engineer
# backend developer
# designer (ui/ux)
# data scientist
# product manager
# mobile developer
# mobile developer
# qa engineer
# product manager
# software engineer
# software engineer
# qa engineer
# devops
# software engineer
# backend developer
# software engineer
# qa engineer
# software engineer
# software engineer
# software engineer
# software engineer
# software engineer
# nlp engineer
# software engineer
# mobile developer
# mobile developer
# working student (qa)
# backend developer
# software engineer
# architect
# software engineer
# backend developer
# frontend developer
# qa engineer
# backend developer
# frontend developer
# data scientist
# head of engineering
# backend developer
# product manager
# qa engineer
# sap consultant
# data scientist
# devops
# product manager
# product manager
# devops
# devops
# backend developer
# mobile developer
# software engineer
# mobile developer
# software engineer
# backend developer
# software engineer
# frontend developer
# qa engineer
# software engineer
# data scientist
# bi consultant sap/ data engineer
# devops
# data engineer
# devops
# backend developer
# software engineer
# backend developer
# business analyst
# backend developer
# frontend developer
# data scientist
# frontend developer
# data engineer
# devops
# qa engineer
# engineering manager
# software engineer
# software engineer
# frontend developer
# devops
# data engineer
# backend developer
# backend developer
# mobile developer
# mobile developer
# frontend developer
# qa engineer
# backend developer
# backend developer
# devops
# frontend developer
# product manager
# software engineer
# frontend developer
# backend developer
# backend developer
# qa engineer
# computer vision researcher
# backend developer
# software engineer
# teamlead
# software engineer
# software engineer
# engineering manager
# backend developer
# backend developer
# software engineer
# software engineer
# software engineer
# hardware engineer
# backend developer
# nlp engineer
# mobile developer
# software engineer
# software engineer
# devops
# mobile developer
# qa engineer
# software engineer
# software engineer
# software engineer
# backend developer
# data scientist
# data scientist
# mobile developer
# frontend developer
# software engineer
# backend developer
# software engineer
# data engineer
# designer (ui/ux)
# data scientist
# sap consultant
# software engineer
# software engineer
# software engineer
# engineering manager
# backend developer
# devops
# fullstack developer
# senior data engineer
# frontend developer
# frontend developer
# software engineer
# qa engineer
# devops
# analyst
# software engineer
# software engineer
# it manager
# qa engineer
# mobile developer
# qa engineer
# head of it
# engineering manager
# software engineer
# software engineer
# backend developer
# mobile developer
# data scientist
# software engineer
# product manager
# qa engineer
# data scientist
# frontend developer
# software engineer
# devops
# lead software developer
# software engineer
# backend developer
# software engineer
# software engineer
# data engineer
# backend developer
# data scientist
# software engineer
# data engineer
# software engineer
# nlp engineer
# software engineer
# software engineer
# tech recruiting
# data scientist
# software engineer
# nlp engineer
# software engineer
# nlp engineer
# nlp engineer
# data scientist
# nlp engineer
# product manager
# mobile developer
# data scientist
# nlp engineer
# software engineer
# data scientist
# software engineer
# nlp engineer
# data scientist
# software engineer
# nlp engineer
# backend developer
# cto
# software engineer
# data scientist
# data analyst
# data scientist
# data analyst
# backend developer
# backend developer
# software engineer
# analyst
# software engineer
# software engineer
# nlp engineer
# frontend developer
# software engineer
# bi developer / data engineer
# devops
# nlp engineer
# qa engineer
# data scientist
# frontend developer
# software engineer
# backend developer
# data scientist
# nlp engineer
# backend developer
# data scientist
# software engineer
# backend developer
# product manager
# senior scrum master (rte)
# qa engineer
# backend developer
# software engineer
# head of bi
# qa engineer
# software engineer
# data scientist
# sre
# technical project manager
# product manager
# support engineer
# frontend developer
# software engineer
# frontend developer
# backend developer
# backend developer
# software engineer
# software engineer
# software engineer
# data engineer
# qa engineer
# software engineer
# security engineer
# data scientist
# devops
# software engineer
# software engineer
# nlp engineer
# software architect
# frontend developer
# backend developer
# software engineer
# software engineer
# frontend developer
# nlp engineer
# software engineer
# data scientist
# qa engineer
# backend developer
# data scientist
# software engineer
# data scientist
# data engineer
# designer (ui/ux)
# business analyst
# software engineer
# qa engineer
# software engineer
# backend developer
# data scientist
# data scientist
# data analyst
# data scientist
# cto
# nlp engineer
# data scientist
# data scientist
# software engineer
# data scientist
# nlp engineer
# it manager
# data scientist
# professor
# backend developer
# data scientist
# ai management
# backend developer
# frontend developer
# data scientist
# sales
# software engineer
# software engineer
# backend developer
# backend developer
# rpa developer
# data scientist
# data scientist
# devops
# devops
# backend developer
# data engineer
# data scientist
# frontend developer
# software engineer
# backend developer
# devops
# backend developer
# student, software developer, data engineer
# head of engineering
# software engineer
# data scientist
# nlp engineer
# data scientist
# devops
# data analyst
# software engineer
# backend developer
# data scientist
# data scientist
# frontend developer
# frontend developer
# nlp engineer
# software engineer
# software engineer
# product manager
# software engineer
# data scientist
# software engineer
# product manager
# data engineer
# data scientist
# devops
# software engineer
# software engineer
# software engineer
# dataops team lead
# backend developer
# software engineer
# data scientist
# software engineer
# software engineer
# software engineer
# software sales
# qa engineer
# backend developer
# software engineer
# software engineer
# product manager
# software engineer
# software engineer
# devops
# beikoch
# software engineer
# product management praktikant
# data scientist
# frontend developer
# backend developer
# mobile developer
# qa engineer
# data analyst
# software engineer
# data scientist
# qa engineer
# software engineer
# data scientist
# data analyst
# software engineer
# software engineer
# designer (ui/ux)
# software engineer
# software engineer
# software engineer
# frontend developer
# backend developer
# software engineer
# product analyst
# software engineer
# qa engineer
# devops
# software engineer
# devops
# qa engineer
# software engineer
# software engineer
# software engineer
# backend developer
# frontend developer
# backend developer
# backend developer
# software engineer
# software engineer
# devops
# team lead
# software engineer
# backend developer
# backend developer
# backend developer
# frontend developer
# data scientist
# software engineer
# it consulting
# software engineer
# nlp engineer
# software engineer
# data scientist
# data scientist
# data scientist
# software engineer
# backend developer
# backend developer
# product manager
# nlp engineer
# frontend developer
# data scientist
# software engineer
# software engineer
# cto
# designer (ui/ux)
# data architect
# software engineer
# software engineer
# nlp engineer
# software engineer
# data scientist
# data scientist
# backend developer
# software engineer
# it manager
# nlp engineer
# backend developer
# backend developer
# qa engineer
# designer (ui/ux)
# software engineer
# head of it
# backend developer
# computational linguist
# rentner
# product analyst
# data scientist
# data engineer
# data scientist
# backend developer
# software engineer
# data engineer
# technical business analyst
# software engineer
# qa engineer
# frontend developer
# software engineer
# data scientist
# data scientist
# devops
# product manager
# devops
# software engineer
# devops
# software engineer
# fullstack developer
# devops
# data scientist
# devops
# backend developer
# backend developer
# devops
# software engineer
# software engineer
# product manager
# frontend developer
# nlp engineer
# cto
# data scientist
# qa manager
# mobile developer
# mobile developer
# software engineer
# product manager
# software engineer
# backend developer
# qa lead
# nlp engineer
# designer (ui/ux)
# software engineer
# backend developer
# robotics engineer
# nlp engineer
# software engineer
# data scientist
# devops
# backend developer
# software engineer
# software engineer
# data scientist
# software engineer
# data scientist
# software engineer
# software engineer
# qa engineer
# software engineer
# mobile developer
# data engineer
# frontend developer
# data engineer
# backend developer
# product manager
# software engineer
# backend developer
# backend developer
# mobile developer
# software engineer
# engineering manager
# software engineer
# nlp engineer
# backend developer
# nan
# nan
# software engineer
# data engineer
# frontend developer
# product manager
# data scientist
# software engineer
# backend developer
# software engineer
# qa engineer
# software engineer
# application consultant
# frontend developer
# team lead
# backend developer
# mobile developer
# software engineer
# software engineer
# devops
# sap consultant
# software engineer
# qa engineer
# software engineer
# backend developer
# backend developer
# software engineer
# backend developer
# rpa developer
# software engineer
# mobile developer
# data scientist
# frontend developer
# software engineer
# backend developer
# software engineer
# backend developer
# backend developer
# software engineer
# mobile developer
# software engineer
# software architect
# software engineer
# software engineer
# backend developer
# frontend developer
# software engineer
# frontend developer
# software engineer
# nlp engineer
# software engineer
# nan
# software engineer
# testmanager
# product manager
# product manager
# qa engineer
# mobile developer
# software engineer
# data analyst
# data scientist
# sre
# sap consultant
# qa engineer
# software engineer
# frontend developer
# head of engineering
# software engineer
# backend developer
# researcher/ consumer insights analyst
# it operations manager
# frontend developer
# devops
# fullstack developer
# backend developer
# mobile developer
# backend developer
# embedded developer
# machine learning engineer
# backend developer
# it manager
# mobile developer
# mobile developer
# fullstack developer
# backend developer
# devops
# designer (ui/ux)
# frontend developer
# backend developer
# mobile developer
# backend developer
# devops
# data scientist
# machine learning engineer
# backend developer
# devops
# data engineer
# devops
# devops
# backend developer
# data scientist
# qa
# backend developer
# software architect
# backend developer
# backend developer
# backend developer
# backend developer
# backend developer
# data engineer
# backend developer
# backend developer
# business analyst
# backend developer
# backend developer
# data engineer
# backend developer
# it manager
# backend developer
# backend developer
# backend developer
# backend developer
# fullstack developer
# backend developer
# frontend developer
# data scientist
# data scientist
# data scientist
# mobile developer
# designer (ui/ux)
# machine learning engineer
# backend developer
# mobile developer
# localization
# it manager
# support
# backend developer
# data scientist
# mobile developer
# backend developer
# data scientist
# embedded developer
# devops
# mobile developer
# backend developer
# backend developer
# it manager
# fullstack developer
# qa
# fullstack developer
# backend developer
# backend developer
# backend developer
# data scientist
# qa
# devops
# mobile developer
# devops
# frontend developer
# devops
# backend developer
# qa
# qa
# qa
# system administrator
# backend developer
# product manager
# it manager
# support
# backend developer
# it manager
# backend developer
# frontend developer
# backend developer
# backend developer
# qa
# backend developer
# sap consultant
# qa
# backend developer
# sre
# mobile developer
# mobile developer
# it manager
# software engineer
# backend developer
# data scientist
# system administrator
# devops
# cto (ceo, cfo)
# embedded developer
# software architect
# frontend developer
# devops
# data engineer
# backend developer
# backend developer
# qa
# software architect
# business analyst
# frontend developer
# backend developer
# devops
# software architect
# business analyst
# designer (ui/ux)
# backend developer
# frontend developer
# qa
# fullstack developer
# backend developer
# qa
# qa
# backend developer
# frontend developer
# fullstack developer
# data engineer
# qa
# backend developer
# backend developer
# qa
# embedded developer
# backend developer
# software architect
# fullstack developer
# fullstack developer
# it manager
# backend developer
# sap consultant
# fullstack developer
# backend developer
# mobile developer
# qa
# backend developer
# qa
# backend developer
# devops
# qa
# frontend developer
# backend developer
# frontend developer
# devops
# backend developer
# database developer (dba)
# desktop/unity3d developer
# it manager
# mobile developer
# software architect
# product manager
# devops
# backend developer
# fullstack developer
# it manager
# software architect
# backend developer
# devops
# it manager
# backend developer
# sap consultant
# fullstack developer
# fullstack developer
# mobile developer
# it manager
# backend developer
# backend developer
# devops
# data engineer
# backend developer
# recruiter
# fullstack developer
# data scientist
# backend developer
# qa
# software architect
# backend developer
# backend developer
# frontend developer
# fullstack developer
# fullstack developer
# frontend developer
# data scientist
# backend developer
# frontend developer
# product manager
# backend developer
# backend developer
# frontend developer
# fullstack developer
# system administrator
# business analyst
# qa
# qa
# mobile developer
# backend developer
# qa
# qa
# data scientist
# backend developer
# mobile developer
# cto (ceo, cfo)
# it manager
# devops
# it manager
# it manager
# software architect
# frontend developer
# machine learning engineer
# frontend developer
# frontend developer
# researcher
# mobile developer
# mobile developer
# frontend developer
# fullstack developer
# fullstack developer
# backend developer
# it manager
# backend developer
# frontend developer
# nan
# backend developer
# fullstack developer
# backend developer
# business analyst
# qa
# backend developer
# it manager
# data scientist
# mobile developer
# data scientist
# mobile developer
# software engineer
# data scientist
# frontend developer
# machine learning engineer
# software architect
# backend developer
# backend developer
# backend developer
# software engineer
# machine learning engineer
# fullstack developer
# backend developer
# embedded developer
# mobile developer
# backend developer
# backend developer
# cloud platform engineer
# mobile developer
# fullstack developer
# data engineer
# qa
# software architect
# backend developer
# frontend developer
# backend developer
# data scientist
# machine learning engineer
# devops
# backend developer
# backend developer
# fullstack developer
# designer (ui/ux)
# mobile developer
# backend developer
# researcher
# backend developer
# devops
# qa
# machine learning engineer
# sap consultant
# backend developer
# backend developer
# backend developer
# machine learning engineer
# frontend developer
# software architect
# researcher
# backend developer
# software architect
# backend developer
# backend developer
# data scientist
# lawyer
# backend developer
# backend developer
# software architect
# mobile developer
# data scientist
# backend developer
# backend developer
# embedded developer
# backend developer
# backend developer
# qa
# data scientist
# devops
# data scientist
# devops
# researcher
# data scientist
# business analyst
# backend developer
# backend developer
# it manager
# frontend developer
# backend developer
# data engineer
# mobile developer
# qa
# machine learning engineer
# backend developer
# software architect
# backend developer
# software architect
# data engineer
# backend developer
# data scientist
# fullstack developer
# data scientist
# frontend developer
# devops
# data scientist
# product manager
# backend developer
# frontend developer
# sap consultant
# backend developer
# system administrator
# fullstack developer
# it security
# qa
# backend developer
# backend developer
# backend developer
# machine learning engineer
# backend developer
# software architect
# backend developer
# frontend developer
# devops
# data scientist
# software architect
# fullstack developer
# it manager
# frontend developer
# devops
# mobile developer
# embedded developer
# data engineer
# software architect
# backend developer
# it manager
# devops
# mobile developer
# backend developer
# backend developer
# devops
# data scientist
# cto (ceo, cfo)
# presales engineer
# backend developer
# data scientist
# it manager
# devops
# qa
# data scientist
# devops
# fullstack developer
# backend developer
# devops
# machine learning engineer
# machine learning engineer
# backend developer
# qa
# frontend developer
# data scientist
# backend developer
# mainframe
# machine learning engineer
# backend developer
# frontend developer
# data scientist
# sap consultant
# software architect
# frontend developer
# data scientist
# business analyst
# data scientist
# qa
# it manager
# data scientist
# data engineer
# machine learning engineer
# data scientist
# machine learning engineer
# data scientist
# data scientist
# software architect
# data scientist
# network engineer
# data engineer
# researcher
# it manager
# it manager
# product manager
# data scientist
# data scientist
# data engineer
# machine learning engineer
# backend developer
# frontend developer
# data scientist
# it manager
# frontend developer
# cto (ceo, cfo)
# data engineer
# data scientist
# sre
# data scientist
# data scientist
# data engineer
# data engineer
# data scientist
# software architect
# data scientist
# nlp engineer
# data engineer
# data scientist
# data scientist
# cto (ceo, cfo)
# data scientist
# data scientist
# data scientist
# researcher
# devops
# software architect
# it manager
# machine learning engineer
# machine learning engineer
# backend developer
# data scientist
# data engineer
# researcher
# software engineer
# data scientist
# fullstack developer
# devops
# backend developer
# data engineer
# data scientist
# backend developer
# data scientist
# machine learning engineer
# backend developer
# backend developer
# head of bi
# it manager
# devops
# software architect
# backend developer
# data scientist
# qa
# frontend developer
# data scientist
# software architect
# frontend developer
# backend developer
# data engineer
# machine learning engineer
# support
# qa
# backend developer
# data scientist
# business analyst
# data scientist
# data scientist
# business analyst
# backend developer
# researcher
# fullstack developer
# data scientist
# cto (ceo, cfo)
# data scientist
# it manager
# fullstack developer
# data engineer
# data scientist
# data scientist
# it manager
# it manager
# business analyst
# data scientist
# product manager
# backend developer
# software architect
# fullstack developer
# qa
# backend developer
# devops
# backend developer
# fullstack developer
# backend developer
# backend developer
# backend developer
# backend developer
# backend developer
# qa
# data scientist
# software architect
# data scientist
# backend developer
# fullstack developer
# mobile developer
# data scientist
# data scientist
# fullstack developer
# backend developer
# frontend developer
# data scientist
# frontend developer
# it manager
# backend developer
# data engineer
# software architect
# frontend developer
# backend developer
# backend developer
# business analyst
# devops
# data engineer
# data scientist
# frontend developer
# fullstack developer
# frontend developer
# data engineer
# business analyst
# data scientist
# data scientist
# data scientist
# it manager
# data engineer
# qa
# researcher
# data scientist
# data scientist
# backend developer
# fullstack developer
# mobile developer
# data scientist
# frontend developer
# qa
# frontend developer
# data scientist
# frontend developer
# data scientist
# qa
# database developer (dba)
# data scientist
# qa
# frontend developer
# data scientist
# machine learning engineer
# head of engineering
# devops
# backend developer
# backend developer
# backend developer
# it manager
# backend developer
# backend developer
# backend developer
# sap consultant
# backend developer
# backend developer
# backend developer
# system administrator
# data scientist
# software engineer
# backend developer
# qa
# data scientist
# fullstack developer
# tech lead
# mobile developer
# software architect
# backend developer
# it manager
# mobile developer
# fullstack developer
# qa
# data scientist
# frontend developer
# qa
# data engineer
# machine learning engineer
# mobile developer
# it manager
# data scientist
# fullstack developer
# frontend developer
# fullstack developer
# software architect
# backend developer
# backend developer
# backend developer
# it manager
# embedded developer
# machine learning engineer
# software engineer
# embedded developer
# data scientist
# cloud platform engineer
# fullstack developer
# fullstack developer
# backend developer
# data scientist
# backend developer
# backend developer
# cto (ceo, cfo)
# embedded developer
# crypto developer
# backend developer
# embedded developer
# data scientist
# qa
# data scientist
# frontend developer
# backend developer
# product manager
# it manager
# data scientist
# data scientist
# cloud platform engineer
# machine learning engineer
# data scientist
# data engineer
# software architect
# it manager
# data engineer
# machine learning engineer
# data scientist
# backend developer
# data scientist
# backend developer
# backend developer
# fullstack developer
# backend developer
# fullstack developer
# data engineer
# frontend developer
# qa
# devops
# data scientist
# it manager
# software architect
# data scientist
# frontend developer
# frontend developer
# fullstack developer
# data scientist
# backend developer
# data scientist
# backend developer
# embedded developer
# product manager
# data scientist
# machine learning engineer
# data scientist
# fullstack developer
# backend developer
# backend developer
# it manager
# data scientist
# backend developer
# frontend developer
# backend developer
# data engineer
# devops
# backend developer
# mobile developer
# data scientist
# fullstack developer
# backend developer
# qa
# backend developer
# backend developer
# backend developer
# fullstack developer
# frontend developer
# it manager
# data scientist
# fullstack developer
# devops
# fullstack developer
# data scientist
# backend developer
# backend developer
# backend developer
# backend developer
# frontend developer
# backend developer
# data scientist
# product manager
# frontend developer
# backend developer
# backend developer
# mobile developer
# backend developer
# fullstack developer
# backend developer
# backend developer
# backend developer
# backend developer
# devops
# backend developer
# mobile developer
# sre
# fullstack developer
# fullstack developer
# backend developer
# backend developer
# machine learning engineer
# devops
# data scientist
# it manager
# it manager
# data scientist
# backend developer
# data scientist
# sre
# head of engineering
# fullstack developer
# fullstack developer
# data scientist
# system administrator
# data scientist
# devops
# fullstack developer
# network engineer
# it manager
# it manager
# frontend developer
# it manager
# devops
# qa
# frontend developer
# it manager
# modelling specialist
# sap consultant
# machine learning engineer
# backend developer
# data engineer
# data engineer
# frontend developer
# system administrator
# backend developer
# backend developer
# qa
# backend developer
# machine learning engineer
# business analyst
# data scientist
# backend developer
# backend developer
# cloud platform engineer
# rpa developer
# tech lead
# qa
# backend developer
# frontend developer
# it manager
# data scientist
# frontend developer
# machine learning engineer
# backend developer
# frontend developer
# mobile developer
# data scientist
# backend developer
# data scientist
# backend developer
# frontend developer
# fullstack developer
# devops
# it manager
# devops
# backend developer
# backend developer
# software architect
# qa
# software architect
# backend developer
# backend developer
# researcher
# fullstack developer
# backend developer
# backend developer
# data scientist
# backend developer
# it manager
# fullstack developer
# fullstack developer
# fullstack developer
# cloud platform engineer
# fullstack developer
# it security
# it manager
# researcher
# it manager
# data scientist
# machine learning engineer
# cloud platform engineer
# network engineer
# data engineer
# backend developer
# rpa developer
# fullstack developer
# sap consultant
# data engineer
# backend developer
# backend developer
# machine learning engineer
# fullstack developer
# fullstack developer
# data scientist
# data engineer
# it manager
# backend developer
# backend developer
# backend developer
# mobile developer
# data scientist
# embedded developer
# support
# it manager
# backend developer
# software engineer
# sre
# fullstack developer
# data scientist
# data scientist
# qa
# backend developer
# data scientist
# backend developer
# software architect
# backend developer
# fullstack developer
# backend developer
# backend developer
# backend developer
# backend developer
# backend developer
# backend developer
# it manager
# backend developer
# frontend developer
# fullstack developer
# qa
# backend developer
# it manager
# backend developer & team lead
# mobile developer
# devops
# support
# qa
# frontend developer
# devops
# sre
# sre
# backend developer
# backend developer
# mobile developer
# backend developer
# data engineer
# backend developer
# frontend developer
# mobile developer
# data engineer
# devops manager
# backend developer
# researcher
# frontend developer
# fullstack developer
# backend developer
# backend developer
# mobile developer
# sre
# backend developer
# mobile developer
# devops
# fullstack developer
# solution architect
# fullstack developer
# sre
# frontend developer
# fullstack developer
# fullstack developer
# tech lead
# scrum master
# backend developer
# database developer (dba)
# it manager
# backend developer
# data analyst
# business analyst
# backend developer
# backend developer
# data engineer
# backend developer
# qa
# mobile developer
# mobile developer
# fullstack developer
# it manager
# backend developer
# backend developer
# data scientist
# mobile developer
# backend developer
# cloud platform engineer
# it manager
# devops
# fullstack developer
# backend developer
# backend developer
# qa
# qa
# embedded developer
# business analyst
# backend developer
# devops
# it manager
# it manager
# it manager
# fullstack developer
# devops
# frontend developer
# researcher
# sap consultant
# fullstack developer
# devops
# mobile developer
# backend developer
# desktop
# qa
# business analyst
# devops
# product manager
# backend developer
# frontend developer
# frontend developer
# data scientist
# data engineer
# sre
# backend developer
# backend developer
# business analyst
# backend developer
# security engineer
# it manager
# software architect
# fullstack developer

# %%
# select top 23 frequent positions 
pos_list = df['Position'].value_counts().iloc[:23].index.tolist()
df = df[df['Position'].isin(pos_list)]

# %%
def clean_senior_col(df):
    meaninigless_values = ['nan','student','working student','no idea, there are no ranges in the firm','no level','no level ']
    df = df[~df['Seniority'].isin(meaninigless_values)]
    return df

# %%
######################################### Draw histogram for positions in the dataset ############################
import matplotlib.pyplot as plt
# create a histogram
plt.figure(figsize=(40,7))
sns.countplot(x = 'Position', data = df, palette = 'pastel',order=df['Position'].value_counts().index)
plt.title('distribution of Position in the dataset ')
plt.show()

# %%
################################ Precentage for each position #######################################3

# %%
plt.figure(figsize=(30,30))
df['Position'].value_counts().iloc[:23].plot.pie(autopct="%1.2f%%",fontsize=13,startangle=90,labels=['']*23)
plt.ylabel("")
plt.legend(loc='upper right',labels=df['Position'].value_counts().iloc[:23].index)
plt.show()

# %% [markdown]
# #### Comments
# 1. It seems that the most frequent position in the data is backend developer(21%),sofware engineer(19%) and data scientist (10%) the least one is administrator

# %%
######################## END OF EXPLORING POSITIONS #######################

# %%
print(df['City'].value_counts().index.tolist())
# Out:
# ['berlin', 'munich', 'amsterdam', 'frankfurt', 'hamburg', 'stuttgart', 'cologne', 'moscow', 'düsseldorf', 'kyiv', 'london', 'zurich', 'nuremberg', 'karlsruhe', 'prague', 'warsaw', 'stuttgart ', 'stockholm', 'heidelberg', 'eindhoven', 'paris', 'tallinn', 'darmstadt', 'helsinki', 'hannover', 'vienna', 'wolfsburg', 'bonn', 'milan', 'wroclaw', 'mannheim', 'leipzig', 'düsseldorf ', 'ingolstadt', 'dusseldorf', 'nürnberg', 'walldorf', 'siegen', 'minsk', 'regensburg', 'barcelona', 'schleswig-holstein', 'lisbon', 'dublin', 'koblenz', 'bielefeld', 'krakow', 'saint-petersburg', 'zug', 'saint petersburg', 'rotterdam', 'rome', 'madrid', 'dresden', 'boeblingen', 'rosenheim', 'utrecht', 'kiev', 'bodensee', 'brussels', 'karlsruhe ', 'cork', 'odesa', 'marburg', 'kassel ', 'pforzheim', 'toulouse', 'freiburg', 'bern', 'riga', 'ma', 'saarbrücken', 'samara', 'ingolstadt ', 'riga, latvia', 'aachen', 'sevilla', 'jyvaskyla', 'lugano', 'dubai', 'limassol', 'nizhny novgorod ', 'lausanne', 'bremen', 'würzburg ', 'antwerpen', 'tuttlingen', 'bayern', 'tampere', 'gothenburg', 'lingen', 'gdańsk', 'hilversum', 'leeuwarden', 'eindhoven ', 'köln', 'kaiserslautern', 'braunschweig', 'cambridge', 'copenhagen', 'fr', 'duesseldorf', 'dortmund', 'france', 'konstanz area', 'friedrichshafen', 'marseille', 'kempten', 'moldova', 'bucharest', 'bölingen', 'erlangen', 'malta', 'ulm', 'konstanz', 'paderborn', 'dublin ', 'münster', 'cupertino', 'lübeck', 'warsaw, poland', 'jena', 'ansbach', 'city in russia', 'nuremberg ', 'dusseldurf', 'prefer not to say', 'hildesheim ', 'brussels ', 'innsbruck', 'heidelberg ', 'hildesheim', 'istanbul', 'basel', 'würzburg', 'luttich', 'sofia', 'den haag', 'cracovia', 'brunswick', 'cracow', 'saint-petersburg ']

# %%
# Explore distribution of City
# get top 12 Cities (their value_counts >= 34)
print(df['City'].value_counts().iloc[:6])
# Out:
# City
# berlin       1039
# munich        440
# amsterdam      85
# frankfurt      83
# hamburg        68
# stuttgart      34
# Name: count, dtype: int64

# %%
# Top 5 City on the survey 
plt.figure(figsize=(8,8))
df['City'].value_counts().iloc[:6].plot.pie(autopct="%1.2f%%",fontsize=9,startangle=90,labels=['']*6)
plt.ylabel("")
plt.legend(loc='upper left',labels=df['City'].value_counts().iloc[:6].index)
plt.show()

# %%
# get the top 6 cities 
# city_remain_values = ['berlin','munich','frankfurt','amsterdam','hamburg','stuttgart','cologne','moscow','düsseldorf','kyiv','london']
city_remain_values = ['berlin','munich','frankfurt','amsterdam','hamburg','stuttgart']
df =df.loc[df['City'].isin(city_remain_values)]

# %% [markdown]
# #### Comment:
# 1. it seems that the most frequent city is Berlin then the cities frequency is ordered as follow Munich,Frankfurt,Amsterdam,Hamburg,Stuttgart.

# %%
######################## END OF EXPLORING Cities #######################

# %%
####################### Start Exploring Salary ##########################

# %%
####################### Salary Cleaning ##################################
# Detect nans in Salary 
print(df[df['Salary'] == 'nan'])
# as there is only one row with nan value we can drop it 
df = df[df['Salary'] != 'nan']
# Out:
#                Timestamp  Age Gender     City           Position
# 475  04.12.2019 19:19:26  nan   male  hamburg  backend developer  \
#
#     Experience_Years Seniority Main_Tech Salary Salary_Bonus Last_Year_Salary
# 475               18    junior    python    nan          nan              nan  \
#
#     Last_Year_Salary_Bonus Vacations Contract_Duration Main_Language_Work
# 475                    nan       nan         unlimited            english  \
#
#     Company_Size Company_Type
# 475        1000+      product

# %%
#  Get some statistical analysis about the Salary 
import numpy as np
import statistics as stats

df_salary = df.copy()



df_salary_mean = df.copy()
df_salary_median = df.copy()
df_salary_mode = df.copy()
df_salary_max = df.copy()
df_salary_min = df.copy()

df_salary_mean['Salary'] = df_salary_mean['Salary'].astype(float)
df_salary_median['Salary'] = df_salary_median['Salary'].astype(float)
df_salary_mode['Salary'] = df_salary_mode['Salary'].astype(float)
df_salary_max['Salary'] = df_salary_max['Salary'].astype(float)
df_salary_min['Salary'] = df_salary_min['Salary'].astype(float)

mean_salary = df_salary_mean['Salary'].mean()
median_salary = df_salary_median['Salary'].median()
mode_salary = df_salary_mode['Salary'].mode()[0]
max_salary = max(df_salary_max['Salary'])
min_salary = min(df_salary_min['Salary'])

# print table 
cal_salary = {'statistic':['mean','median','mode','max','min'],'value':[mean_salary,median_salary,mode_salary,max_salary,min_salary]}
table = pd.DataFrame(cal_salary)
table_str = table.to_string(index=False, justify='center')
print(table_str)
# Out:
# statistic      value
#     mean   73765.974828
#   median   70000.000000
#     mode   70000.000000
#      max  850000.000000
#      min   10001.000000

# %%
###################### draw the slary disripution ######################
plt.hist(df_salary['Salary'], bins=50, alpha=0.8, color='green', edgecolor='black')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.title('Salary Distribution')
plt.show()

# %%
# create box plot
plt.boxplot(df_salary['Salary'],patch_artist=True,boxprops=dict(facecolor='blue', color='black'))
# set labels and title
plt.xlabel('Salary')
plt.ylabel('Value')
plt.title('Salary Box Plot')
# plt.ylim(0, 800000)
# show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 # create box plot
# ----> 2 plt.boxplot(df_salary['Salary'],patch_artist=True,boxprops=dict(facecolor='blue', color='black'))
#       3 # set labels and title
#       4 plt.xlabel('Salary')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\pyplot.py:2483, in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, data)
#    2473 @_copy_docstring_and_deprecators(Axes.boxplot)
#    2474 def boxplot(
#    2475         x, notch=None, sym=None, vert=None, whis=None,
#    (...)
#    2481         whiskerprops=None, manage_ticks=True, autorange=False,
#    2482         zorder=None, capwidths=None, *, data=None):
# -> 2483     return gca().boxplot(
#    2484         x, notch=notch, sym=sym, vert=vert, whis=whis,
#    2485         positions=positions, widths=widths, patch_artist=patch_artist,
#    2486         bootstrap=bootstrap, usermedians=usermedians,
#    2487         conf_intervals=conf_intervals, meanline=meanline,
#    2488         showmeans=showmeans, showcaps=showcaps, showbox=showbox,
#    2489         showfliers=showfliers, boxprops=boxprops, labels=labels,
#    2490         flierprops=flierprops, medianprops=medianprops,
#    2491         meanprops=meanprops, capprops=capprops,
#    2492         whiskerprops=whiskerprops, manage_ticks=manage_ticks,
#    2493         autorange=autorange, zorder=zorder, capwidths=capwidths,
#    2494         **({"data": data} if data is not None else {}))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\__init__.py:1459, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1456 @functools.wraps(func)
#    1457 def inner(ax, *args, data=None, **kwargs):
#    1458     if data is None:
# -> 1459         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1461     bound = new_sig.bind(ax, *args, **kwargs)
#    1462     auto_label = (bound.arguments.get(label_namer)
#    1463                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\axes\_axes.py:3914, in Axes.boxplot(self, x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths)
#    3911 if bootstrap is None:
#    3912     bootstrap = mpl.rcParams['boxplot.bootstrap']
# -> 3914 bxpstats = cbook.boxplot_stats(x, whis=whis, bootstrap=bootstrap,
#    3915                                labels=labels, autorange=autorange)
#    3916 if notch is None:
#    3917     notch = mpl.rcParams['boxplot.notch']
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\cbook\__init__.py:1232, in boxplot_stats(X, whis, bootstrap, labels, autorange)
#    1229 x = np.asarray(x)
#    1231 # arithmetic mean
# -> 1232 stats['mean'] = np.mean(x)
#    1234 # medians and quartiles
#    1235 q1, med, q3 = np.percentile(x, [25, 50, 75])
#
# File <__array_function__ internals>:200, in mean(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\numpy\core\fromnumeric.py:3464, in mean(a, axis, dtype, out, keepdims, where)
#    3461     else:
#    3462         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3464 return _methods._mean(a, axis=axis, dtype=dtype,
#    3465                       out=out, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\numpy\core\_methods.py:194, in _mean(a, axis, dtype, out, keepdims, where)
#     192         ret = ret.dtype.type(ret / rcount)
#     193 else:
# --> 194     ret = ret / rcount
#     196 return ret
#
# TypeError: ufunc 'divide' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %% [markdown]
# statistic      value
#     mean     73765.974828
#     median   70000.000000
#     mode     70000.000000
#     max      850000.000000
#     min      10001.000000

# %% [markdown]
# #### Comments:
# 1. It seems from the data that the the average salary for IT jobs in general is around 70000 (above or below with 5000)
# 2. From the data also it seems that we have some outliers (the salary for some positions is above 200000)

# %%
######################## START EXPLORING sENIORITY LEVEL#################################

# %%
# CHECK THE NULLS IN SENIORITY LEVEL 
df_seniority = df.copy()
print(df_seniority['Seniority'].value_counts())
# clean Seniority Level 
'''
1- principal can be mapped to senior 
2- remove senior levels < 2
'''
def clean_senior_col(df):
    meaninigless_values = ['nan','student','working student','no idea, there are no ranges in the firm','no level','no level ']
    df = df[~df['Seniority'].isin(meaninigless_values)]
    for i, row in df.iterrows():
            if row['Seniority'] in ['principal']:
                df.at[i,'Seniority'] = 'senior'
    seniority_counts = df['Seniority'].value_counts()
    seniority_counts = seniority_counts[seniority_counts >= 2]
    df = df[df['Seniority'].isin(seniority_counts.index)]
    return df
# Out:
# Seniority
# senior             944
# middle             488
# lead               163
# junior              96
# head                28
# nan                 19
# principal            5
# no level             1
# intern               1
# working student      1
# student              1
# self employed        1
# Name: count, dtype: int64

# %%
df_seniority = clean_senior_col(df_seniority)
seniority_remain_values = df_seniority['Seniority'].value_counts()

# %%
plt.figure(figsize=(12,8))
sns.barplot(y=seniority_remain_values.index,x= seniority_remain_values,palette='Pastel1')
plt.xlabel("Average Salary",fontsize=14)
plt.ylabel("Positins in Berlin",fontsize=14)
plt.show()

# %%
plt.figure(figsize=(8,8))
df_seniority['Seniority'].value_counts().iloc[:5].plot.pie(autopct="%1.2f%%",fontsize=9,startangle=90,labels=['']*5)
plt.ylabel("")
plt.legend(loc='upper left',labels=df['Seniority'].value_counts().iloc[:5].index)
plt.show()

# %% [markdown]
# #### Comments:
# 1. From the data it seems that the most frequent senior level is senior with precentage (55% around half of the data)

# %%
######################## START EXPLORE SENIORS SALARIES IN BERLIN ONLY #######################

# %%
# get Berlin only 
df_Brlin = df.copy()
df_Brlin = df[df['City'] == 'berlin']

# %%
################################# Salayries Juniors ########################################

# %%
# get seniors only
df_Brlin = df_Brlin[df_Brlin['Seniority'] == 'senior']

# %%
#TODO: this cell should be removed 
print(df_Brlin[df_Brlin['Position']=='nlp engineer'])
# Out:
#                Timestamp   Age Gender    City      Position Experience_Years
# 284  24/11/2020 15:10:18  42.0   male  berlin  nlp engineer               20  \
# 298  24/11/2020 15:41:45  34.0   male  berlin  nlp engineer               12
# 676  25/11/2020 18:59:36  33.0   male  berlin  nlp engineer               10
# 850  27/11/2020 14:45:29  27.0   male  berlin  nlp engineer                5
# 987  30/11/2020 19:28:15  34.0   male  berlin  nlp engineer                3
# 453  04.12.2019 16:33:24  38.0   male  berlin  nlp engineer                4
#
#     Seniority Main_Tech   Salary Salary_Bonus Last_Year_Salary
# 284    senior    python  80000.0          nan          66000.0  \
# 298    senior    python  90000.0          nan          80000.0
# 676    senior       nan  90000.0          nan              nan
# 850    senior    python  70000.0          nan              nan
# 987    senior    python  70000.0          nan          55000.0
# 453    senior    python  65000.0          nan              nan
#
#     Last_Year_Salary_Bonus Vacations   Contract_Duration Main_Language_Work
# 284                    nan        30  unlimited contract             german  \
# 298                    nan        27  unlimited contract            english
# 676                    nan       nan  unlimited contract            english
# 850                    nan       nan                 nan                nan
# 987                    nan        30  temporary contract            english
# 453                    nan      26.0           unlimited            english
#
#     Company_Size Company_Type
# 284        1000+      product
# 298        1000+      product
# 676        1000+      product
# 850          nan          nan
# 987     101-1000      product
# 453     100-1000      startup

# %%
######################## GET AVG SALARIES IN BERLIN  #######################

# %%
# convert column 'Salary' to a numeric data type
df_Brlin['Salary'] = pd.to_numeric(df_Brlin['Salary'])
position_salary = df_Brlin.groupby('Position')['Salary'].sum()
position_salary.sort_values(ascending=False,inplace=True)
position_avg_salary = (position_salary/ df_Brlin['Position'].value_counts()).sort_values(ascending = False)
top_position = position_avg_salary.index.to_list()
print(position_avg_salary)
# Out:
# Position
# researcher                   106000.000000
# system administrator          96000.000000
# sap consultant                96000.000000
# machine learning engineer     94000.000000
# software architect            91800.000000
# frontend developer            90322.857143
# data scientist                84235.869565
# it manager                    82717.647059
# data engineer                 81391.304348
# data analyst                  80000.000000
# sre                           79200.000000
# nlp engineer                  77500.000000
# software engineer             76599.494949
# devops                        75592.307692
# backend developer             75266.058442
# product manager               73111.111111
# business analyst              72000.000000
# fullstack developer           71047.619048
# mobile developer              70917.857143
# embedded developer            66250.000000
# qa                            66070.731707
# designer (ui/ux)              58440.000000
# dtype: float64

# %%
plt.figure(figsize=(12,8))
print(position_salary)
sns.barplot(y=top_position,x= position_avg_salary,palette='Pastel1')
plt.xlabel("Average Salary",fontsize=14)
plt.ylabel("Positins in Berlin",fontsize=14)
plt.show()
# Out:
# Position
# backend developer            11590973.0
# software engineer             7583350.0
# data scientist                3874850.0
# frontend developer            3793560.0
# qa                            2708900.0
# mobile developer              1985700.0
# devops                        1965400.0
# data engineer                 1872000.0
# fullstack developer           1492000.0
# it manager                    1406200.0
# software architect            1101600.0
# product manager                658000.0
# designer (ui/ux)               584400.0
# machine learning engineer      470000.0
# nlp engineer                   465000.0
# sre                            396000.0
# embedded developer             265000.0
# business analyst               216000.0
# researcher                     212000.0
# sap consultant                 192000.0
# data analyst                   160000.0
# system administrator            96000.0
# Name: Salary, dtype: float64

# %%
#################################### END SALARY ANALYSIS IN BERLIN FOR SENIORS #################################

# %%
######################## START EXPLORE SENIORS SALARIES IN MUNICH ONLY  #######################

# %%
# get Munich only 
df_Muinch = df.copy()
df_Muinch = df[df['City'] == 'munich']
# get seniors only
df_Muinch = df_Muinch[df_Muinch['Seniority'] == 'senior']

# %%
#TODO: this cell should be removed 
print(df_Muinch[df_Muinch['Position']=='researcher'])
# Out:
#                Timestamp   Age  Gender    City    Position Experience_Years
# 236  02.12.2019 20:34:52  25.0  female  munich  researcher                5  \
# 292  03.12.2019 10:13:04  34.0    male  munich  researcher               12
# 304  03.12.2019 10:39:01   nan    male  munich  researcher                9
#
#     Seniority Main_Tech    Salary Salary_Bonus Last_Year_Salary
# 236    middle     c/c++   57000.0          nan              nan  \
# 292    senior     c/c++   90000.0      22500.0              nan
# 304    senior    python  130000.0      18000.0              nan
#
#     Last_Year_Salary_Bonus Vacations Contract_Duration Main_Language_Work
# 236                    nan      28.0         unlimited            english  \
# 292                    nan      30.0         unlimited            english
# 304                    nan      30.0         unlimited            english
#
#     Company_Size         Company_Type
# 236        1000+  consulting / agency
# 292     100-1000              product
# 304        1000+              product

# %%
######################## GET AVG SALARIES IN BERLIN  #######################
df_Muinch['Salary'] = pd.to_numeric(df_Muinch['Salary'])
position_salary = df_Muinch.groupby('Position')['Salary'].sum()
position_salary.sort_values(ascending=False,inplace=True)
position_avg_salary = (position_salary/ df_Muinch['Position'].value_counts()).sort_values(ascending = False)
top_position = position_avg_salary.index.to_list()
print(position_avg_salary)
# Out:
# Position
# nlp engineer           140000.000000
# researcher             110000.000000
# software architect     103375.000000
# sap consultant          97000.000000
# data analyst            95000.000000
# it manager              93333.333333
# devops                  90545.454545
# data scientist          89562.500000
# backend developer       79348.979592
# software engineer       78927.440000
# fullstack developer     78308.333333
# mobile developer        77056.250000
# data engineer           74675.000000
# embedded developer      73600.000000
# sre                     73433.333333
# qa                      73410.714286
# business analyst        71500.000000
# frontend developer      71004.545455
# product manager         69500.000000
# designer (ui/ux)        65000.000000
# dtype: float64

# %%
######################## Plot #######################
plt.figure(figsize=(12,8))
print(position_salary)
sns.barplot(y=top_position,x= position_avg_salary,palette='Pastel1')
plt.xlabel("Average Salary",fontsize=14)
plt.ylabel("Positins in Muinch",fontsize=14)
plt.show()
# Out:
# Position
# software engineer      3946372.0
# backend developer      3888100.0
# qa                     2055500.0
# frontend developer     1562100.0
# mobile developer       1232900.0
# it manager             1120000.0
# devops                  996000.0
# fullstack developer     939700.0
# software architect      827000.0
# data scientist          716500.0
# embedded developer      368000.0
# data engineer           298700.0
# sap consultant          291000.0
# business analyst        286000.0
# nlp engineer            280000.0
# sre                     220300.0
# researcher              220000.0
# product manager         139000.0
# designer (ui/ux)        130000.0
# data analyst             95000.0
# Name: Salary, dtype: float64

# %%
######################################## GET AVG SALARIES IN amsterdam ##################################

# %%
# get Munich only 
df_amsterdam = df.copy()
df_amsterdam = df[df['City'] == 'hamburg']
# get seniors only
# df_amsterdam = df_amsterdam[df_amsterdam['Seniority'] == 'senior']

# %%
#TODO: this cell should be removed 
print(df_amsterdam[df_amsterdam['Position']=='researcher'])
# Out:
# Empty DataFrame
# Columns: [Timestamp, Age, Gender, City, Position, Experience_Years, Seniority, Main_Tech, Salary, Salary_Bonus, Last_Year_Salary, Last_Year_Salary_Bonus, Vacations, Contract_Duration, Main_Language_Work, Company_Size, Company_Type]
# Index: []

# %%
######################## GET AVG SALARIES IN BERLIN  #######################
df_amsterdam['Salary'] = pd.to_numeric(df_amsterdam['Salary'])
position_salary = df_amsterdam.groupby('Position')['Salary'].sum()
position_salary.sort_values(ascending=False,inplace=True)
position_avg_salary = (position_salary/ df_amsterdam['Position'].value_counts()).sort_values(ascending = False)
top_position = position_avg_salary.index.to_list()
print(position_avg_salary)
# Out:
# Position
# sre                          107685.000000
# machine learning engineer     90500.000000
# sap consultant                80500.000000
# data engineer                 79800.000000
# data scientist                79000.000000
# devops                        78950.000000
# fullstack developer           77500.000000
# it manager                    77333.333333
# business analyst              74900.000000
# frontend developer            74900.000000
# backend developer             74892.857143
# mobile developer              74200.000000
# qa                            69428.571429
# dtype: float64

# %%
######################## Plot #######################
plt.figure(figsize=(12,8))
print(position_salary)
sns.barplot(y=top_position,x= position_avg_salary,palette='Pastel1')
plt.xlabel("Average Salary",fontsize=14)
plt.ylabel("Positins in Amsterdam",fontsize=14)
plt.show()
# Out:
# Position
# backend developer            1048500.0
# qa                            486000.0
# mobile developer              371000.0
# devops                        315800.0
# data engineer                 239400.0
# it manager                    232000.0
# frontend developer            224700.0
# machine learning engineer     181000.0
# data scientist                158000.0
# fullstack developer           155000.0
# sre                           107685.0
# sap consultant                 80500.0
# business analyst               74900.0
# Name: Salary, dtype: float64

# %% [markdown]
# #### 1- Stating and refining the question.
# ##### Can we infer that the most paying position in Berlin is the highest paid in all other cities?

# %% [markdown]
# #### 2- Exploring the data.

# %%
# Explor Positions in Berlin
df_Mu_pos = df.copy()
df_Mu_pos = df_Mu_pos[df_Mu_pos['City']=='Munich']
# find the distribution between the position and avg Salary

# %%
# df_Mu_pos[df_Mu_pos['Salary']==300000.0]
# Out:
#                Timestamp   Age Gender    City        Position
# 576  25/11/2020 13:26:21  24.0   Male  Munich  Data Scientist  \
#
#     Experience_Years German_Experience Seniority Main_Tech
# 576                1                 1    Junior       C++  \
#
#                                             Other_Tech    Salary
# 576  Python, C/C++, Swift, Java / Scala, R, SQL, Go...  300000.0  \
#
#      Last_Year_Salary     Employee_Status Contract_Duration
# 576               NaN  Full-time employee               NaN  \
#
#     Main_Language_Work Company_Size Company_Type
# 576            English     101-1000      Startup

# %%
# remove all values that appear little in company type 
company_remain_values = ['Product','Startup','Consulting / Agency','Bank','Media']
df =df.loc[df['Company_Type'].isin(company_remain_values)]

# %% [markdown]
# #### 3- Format Modeling to answer the question

# %% [markdown]
# #### 4- Interpreting the results.

# %% [markdown]
# #### 5- Communicating the results.
